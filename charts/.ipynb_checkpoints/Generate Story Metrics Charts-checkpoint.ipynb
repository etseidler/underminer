# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

DAYS_BACK = 60
CYCLETIMES_PATH = '../cycletimes.csv'

CODE_REVIEW = 'Code Review'
TECH_DEBT = 'Tech Debt'
SPIKE = 'Spike'
DESIGN = 'Design'
DAYS_IN_DEV = 'Days in Dev'
TRACKER = 'Tracker'
TASK = 'Task'
BUG = 'Bug'
STORY = 'Story'

YES = 'Yes'
NO = 'No'

# Seaborn options
sns.set(font_scale=2)
sns.set_theme(font_scale=1.5, palette="bright")

# load dataset using pandas
df = pd.read_csv(CYCLETIMES_PATH)
all_df = df
# all_df.info()

# remove design stories
df = df[df[DESIGN] == NO]

# don't look at all data, just last DAYS_BACK days
now = datetime.utcnow()
then = (now - timedelta(days=DAYS_BACK)).isoformat()[:-7]+'Z'
recent_df = df[df[CODE_REVIEW] > then]
# recent_df.info()
df = recent_df


# breakdown by label applied in card title
tech_debt_df = df[df[TECH_DEBT] == YES]
# spikes_df = df[df[SPIKE] == YES]

# breakdown by story type (tracker)
task_df = df[df[TRACKER] == TASK]
bug_df = df[df[TRACKER] == BUG]
story_df = df[df[TRACKER] == STORY]


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 145 to 714
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Issue ID        50 non-null     int64
#  1   Link            50 non-null     object
#  2   Title           50 non-null     object
#  3   Analysis        8 non-null      object
#  4   Ready to Work   48 non-null     object
#  5   In Progress     50 non-null     object
#  6   Code Review     50 non-null     object
#  7   QA              0 non-null      object
#  8   PO              48 non-null     object
#  9   Done            49 non-null     object
#  10  Assignee        0 non-null      object
#  11  Status          50 non-null     object
#  12  Days in Work    49 non-null     float64
#  13  Tech Debt       50 non-null     object
#  14  Parent ID       50 non-null     float64
#  15  Parent Name     34 non-null     object
#  16  Target Version  50 non-null     object
#  17  Tracker         50 non-null     object
#  18  Days in Dev     50 non-null     float64
#  19  Spike           50 non-null     object
#  20  Design          50 non-null     object
# dtypes: float64(3), int64(1), object(17)
# memory usage: 8.6+ KB

# %%
df.head()
# Out:
#      Issue ID                                 Link  \
# 145     53210  https://redmine.gs.mil/issues/53210
# 490     68446  https://redmine.gs.mil/issues/68446
# 502     68979  https://redmine.gs.mil/issues/68979
# 506     69126  https://redmine.gs.mil/issues/69126
# 541     71214  https://redmine.gs.mil/issues/71214
#
#                                                  Title              Analysis  \
# 145              Export shapefile data with projection  2020-01-15T15:37:37Z
# 490        increase validation on uploaded KER profile  2020-10-19T15:00:57Z
# 502  Add contextual information to the 'magnitude' ...  2020-10-19T14:58:27Z
# 506                  Update UI for KER Results/Summary  2020-10-19T14:58:44Z
# 541                        App fails with Null UID/UFI  2020-10-20T16:10:08Z
#
#             Ready to Work           In Progress           Code Review   QA  \
# 145  2021-04-13T20:00:52Z  2021-04-28T14:08:39Z  2021-04-29T18:23:44Z  NaN
# 490  2021-03-30T19:32:21Z  2021-04-05T18:11:49Z  2021-04-07T14:06:15Z  NaN
# 502  2021-03-09T20:32:52Z  2021-03-19T13:09:00Z  2021-03-24T13:52:48Z  NaN
# 506  2021-03-30T19:28:50Z  2021-04-02T14:55:04Z  2021-04-05T17:29:33Z  NaN
# 541  2021-04-13T19:35:38Z  2021-04-26T13:40:48Z  2021-04-28T15:39:34Z  NaN
#
#                        PO                  Done  ... Status Days in Work  \
# 145  2021-04-30T13:16:33Z  2021-04-30T14:20:00Z  ...   Done          2.0
# 490  2021-04-08T14:57:24Z  2021-04-08T17:52:01Z  ...   Done          3.0
# 502  2021-03-29T12:59:41Z  2021-03-29T14:00:37Z  ...   Done         10.0
# 506  2021-04-06T16:45:28Z  2021-04-06T16:54:59Z  ...   Done          4.1
# 541  2021-04-30T13:16:31Z  2021-04-30T14:21:13Z  ...   Done          4.0
#
#      Tech Debt Parent ID            Parent Name  Target Version Tracker  \
# 145         No   82965.0                    NaN    TDS Phase 3     Task
# 490         No   73335.0                    NaN  TDS - Phase II    Task
# 502         No   73302.0                    NaN  TDS - Phase II   Story
# 506         No   73302.0                    NaN  TDS - Phase II    Task
# 541         No   82965.0  KER Condition Outputs    TDS Phase 3      Bug
#
#     Days in Dev  Spike Design
# 145         1.2     No     No
# 490         1.8     No     No
# 502         5.0     No     No
# 506         3.1     No     No
# 541         2.1     No     No
#
# [5 rows x 21 columns]

# %%
def report_stats_on_cards(df)
    print('Number of All Cards*')
    total = len(df)
    print(total)
    print('Average for All Cards*')
    print(round(df[DAYS_IN_DEV].mean(), 2))
    print('Percentage over 2 Days in Dev')
    num_over_2 = len(df[df[DAYS_IN_DEV] > 2])
    print(str(round(num_over_2/total *100)) + '%')
# Out:
# Number of All Cards*
# 50
# Average for All Cards*
# 3.32
# Percentage over 2 Days in Dev
# 64%

# %%
sns.histplot(df, x=DAYS_IN_DEV, discrete=True)
_ = plt.title('All Cards*')
report_

# %%
# the good stuff (plots)

sns.histplot(tech_debt_df, x=DAYS_IN_DEV, discrete=True)
_ = plt.title(TECH_DEBT)

# %%
# sns.histplot(task_df, x=DAYS_IN_DEV, discrete=True)
# _ = plt.title(TASK)

# %%
# sns.histplot(bug_df, x=DAYS_IN_DEV, discrete=True)
# _ = plt.title(BUG)

# %%
# sns.histplot(story_df, x=DAYS_IN_DEV, discrete=True)
# _ = plt.title(STORY)

# %%
g = sns.FacetGrid(df, col=TRACKER)
print('                    Days in Dev by Tracker')
_ = g.map(sns.histplot, DAYS_IN_DEV, discrete=True)
# Out:
#                     Days in Dev by Tracker
